# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('train_data.csv')
test=pd.read_csv('test_data.csv')
train.head()
# Out:
#    age workclass  fnlwgt     education  educational-num      marital-status  \
# 0   49   Private  246183       HS-grad                9  Married-civ-spouse
# 1   57   Private  176904          11th                7  Married-civ-spouse
# 2   50   Private  421561  Some-college               10            Divorced
# 3   24   Private   29810  Some-college               10       Never-married
# 4   21   Private   77572       HS-grad                9       Never-married
#
#           occupation   relationship                race  gender  capital-gain  \
# 0              Sales        Husband               White    Male             0
# 1  Handlers-cleaners        Husband               White    Male             0
# 2    Exec-managerial  Not-in-family               White    Male             0
# 3     Prof-specialty      Own-child               White  Female             0
# 4  Handlers-cleaners  Not-in-family  Asian-Pac-Islander  Female             0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
l_work=LabelEncoder().fit(train['workclass'])
l_marry=LabelEncoder().fit(train['marital-status'])
l_occ=LabelEncoder().fit(train['occupation'])
l_relation=LabelEncoder().fit(train['relationship'])
l_race=LabelEncoder().fit(train['race'])
l_gender=LabelEncoder().fit(train['gender'])
l_country=LabelEncoder().fit(train['native-country'])
l_income=LabelEncoder().fit(train['income'])

# %%
train=train.drop(['education'],axis=1)
test=test.drop(['education'],axis=1)

# %%
for df in train,test:
    df['workclass']=l_work.transform(df['workclass'])
    df['marital-status']=l_marry.transform(df['marital-status'])
    df['occupation']=l_occ.transform(df['occupation'])
    df['relationship']=l_relation.transform(df['relationship'])
    df['race']=l_race.transform(df['race'])
    df['gender']=l_gender.transform(df['gender'])
    df['native-country']=l_country.transform(df['native-country'])

# %%
train['income']=l_income.transform(train['income'])

# %%
fig,arr=plt.subplots(4,4,figsize=(15,15))
arr[0,0].plot(train['workclass'],train['income'],'.')
arr[0,0].set_title('workclass')
arr[0,1].plot(train['fnlwgt'],train['income'],'.')
arr[0,1].set_title('fnlwgt')
arr[1,0].plot(train['educational-num'],train['income'],'.')
arr[1,0].set_title('educational-num')
arr[1,1].plot(train['marital-status'],train['income'],'.')
arr[1,1].set_title('marital-status')
arr[1,2].plot(train['occupation'],train['income'],'.')
arr[1,2].set_title('occupation')
arr[2,0].plot(train['relationship'],train['income'],'.')
arr[2,0].set_title('relationship')
arr[2,1].plot(train['race'],train['income'],'.')
arr[2,1].set_title('race')
arr[2,2].plot(train['gender'],train['income'],'.')
arr[2,2].set_title('gender')
arr[3,0].plot(train['capital-gain'],train['income'],'.')
arr[3,0].set_title('capital-gain')
arr[3,1].plot(train['capital-loss'],train['income'],'.')
arr[3,1].set_title('capital-loss')
arr[3,2].plot(train['hours-per-week'],train['income'],'.')
arr[3,2].set_title('hours-per-week')

plt.show()

# %%
import seaborn as sns
#plt.figure(figsize=(20,20))
#sns.boxplot(data=train)
#plt.show()

# %%
#plt.figure(figsize=(15,15))
#corr = train.corr()
#sns.violinplot(data=corr)
#plt.show()

# %%
'''
fig,arr=plt.subplots(3,4,figsize=(15,15))
arr[0,0]=sns.violinplot(train['workclass'],train['income'])
arr[0,1]=sns.violinplot(train['fnlwgt'],train['income'])
arr[0,2]=sns.violinplot(train['education'],train['income'])
arr[1,0]=sns.violinplot(train['educational-num'],train['income'])
arr[1,1]=sns.violinplot(train['marital-status'],train['income'])
arr[1,2]=sns.violinplot(train['occupation'],train['income'])
arr[2,0]=sns.violinplot(train['relationship'],train['income'])
arr[2,1]=sns.violinplot(train['race'],train['income'])
arr[2,2]=sns.violinplot(train['gender'],train['income'])
arr[3,0]=sns.violinplot(train['capital-gain'],train['income'])
arr[3,1]=sns.violinplot(train['capital-loss'],train['income'])
arr[3,2]=sns.violinplot(train['hours-per-week'],train['income'])

plt.show()
'''
# Out:
# "\nfig,arr=plt.subplots(3,4,figsize=(15,15))\narr[0,0]=sns.violinplot(train['workclass'],train['income'])\narr[0,1]=sns.violinplot(train['fnlwgt'],train['income'])\narr[0,2]=sns.violinplot(train['education'],train['income'])\narr[1,0]=sns.violinplot(train['educational-num'],train['income'])\narr[1,1]=sns.violinplot(train['marital-status'],train['income'])\narr[1,2]=sns.violinplot(train['occupation'],train['income'])\narr[2,0]=sns.violinplot(train['relationship'],train['income'])\narr[2,1]=sns.violinplot(train['race'],train['income'])\narr[2,2]=sns.violinplot(train['gender'],train['income'])\narr[3,0]=sns.violinplot(train['capital-gain'],train['income'])\narr[3,1]=sns.violinplot(train['capital-loss'],train['income'])\narr[3,2]=sns.violinplot(train['hours-per-week'],train['income'])\n\nplt.show()\n"

# %%
plt.figure(figsize=(15,15))
arr=sns.violinplot(train['workclass'],train['income'])
plt.show()

# %%
plt.figure(figsize=(15,15))
arr=sns.kdeplot(train['fnlwgt'],train['income'])
plt.show()

# %%
plt.figure(figsize=(15,15))
arr=sns.violinplot(train['educational-num'],train['income'])
plt.show()

# %%
plt.figure(figsize=(15,15))
arr=sns.violinplot(train['marital-status'],train['income'])
plt.show()

# %%
plt.figure(figsize=(15,15))
arr=sns.violinplot(train['occupation'],train['income'])
plt.show()

# %%
plt.figure(figsize=(15,15))
arr=sns.violinplot(train['relationship'],train['income'])
plt.show()

# %%
plt.figure(figsize=(15,15))
arr=sns.violinplot(train['race'],train['income'])
plt.show()

# %%
plt.figure(figsize=(15,15))
arr=sns.violinplot(train['gender'],train['income'])
plt.show()

# %%
plt.figure(figsize=(15,15))
arr=sns.kdeplot(train['capital-gain'],train['income'])
plt.show()

# %%
plt.figure(figsize=(15,15))
arr=sns.kdeplot(train['capital-loss'],train['income'])
plt.show()

# %%
plt.figure(figsize=(15,15))
arr=sns.kdeplot(train['hours-per-week'],train['income'])
plt.show()

# %%
plt.figure(figsize=(15,15))
arr=sns.kdeplot(train['age'],train['income'])
plt.show()

# %%
plt.figure(figsize=(15,15))
arr=sns.violinplot(train['native-country'],train['income'])
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train.drop(['income'],axis=1), train['income'], test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
extra=ExtraTreesClassifier(n_estimators=200,n_jobs=-1).fit(X_train,y_train).predict(X_test)
accuracy_score(y_test,extra)
# Out:
# 0.85378662244333892

# %%
random=RandomForestClassifier(n_estimators=200,n_jobs=-1).fit(X_train,y_train).predict(X_test)
accuracy_score(y_test,random)
# Out:
# 0.86484245439469321

# %%
decision=DecisionTreeClassifier().fit(X_train,y_train).predict(X_test)
accuracy_score(y_test,decision)
# Out:
# 0.81315644002211163

# %%
from sklearn.naive_bayes import GaussianNB
nv=GaussianNB().fit(X_train,y_train).predict(X_test)
accuracy_score(y_test,nv)
# Out:
# 0.79546710889994476

# %%
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
xgb = XGBClassifier( n_estimators=200, learning_rate=0.001, max_depth=20, subsample=0.9
                   , min_child_weight=4, colsample_bytree=0.7)

boost=xgb.fit(X_train,y_train).predict(X_test)
accuracy_score(y_test,boost)
# Out:
# 0.87313432835820892

# %%
best_prediction=xgb.fit(train.drop(['income'],axis=1), train['income']).predict(test)

# %%
test['income']=l_income.inverse_transform(best_prediction)
test['marital-status']=l_marry.inverse_transform(test['marital-status'])
test['occupation']=l_occ.inverse_transform(test['occupation'])
test['relationship']=l_relation.inverse_transform(test['relationship'])
test['race']=l_race.inverse_transform(test['race'])
test['gender']=l_gender.inverse_transform(test['gender'])
test['native-country']=l_country.inverse_transform(test['native-country'])
    
test.head()
# Out:
#    age  workclass  fnlwgt  educational-num      marital-status  \
# 0   50          4   30731               11       Never-married
# 1   38          2  299810                9  Married-civ-spouse
# 2   23          2  129767               10       Never-married
# 3   39          0  257175               13            Divorced
# 4   45          2  174426               14  Married-civ-spouse
#
#           occupation   relationship   race  gender  capital-gain  \
# 0      Other-service  Not-in-family  White    Male             0
# 1  Handlers-cleaners        Husband  Black    Male             0
# 2       Adm-clerical  Not-in-family  White  Female             0
# 3       Tech-support      Unmarried  Black  Female             0
# 4     Prof-specialty        Husband  White    Male             0
#
#    capital-loss  hours-per-week native-country income
# 0             0              50  United-States  <=50K
# 1             0              40  United-States  <=50K
# ...

# %%
test.to_csv('encoded_predicton.csv',index=False)

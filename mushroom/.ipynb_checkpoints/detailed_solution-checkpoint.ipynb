# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv('mushroom_train.csv')
test=pd.read_csv('mushroom_test.csv')
train.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         f           s         e       f    s               f
# 1     p         x           y         w       t    p               f
# 2     e         f           s         n       t    n               f
# 3     p         x           s         e       f    y               f
# 4     e         x           s         w       t    l               f
#
#   gill-spacing gill-size gill-color   ...    stalk-color-above-ring  \
# 0            c         n          b   ...                         p
# 1            c         n          k   ...                         w
# 2            c         b          e   ...                         e
# 3            c         n          b   ...                         p
# 4            c         b          n   ...                         w
#
#   stalk-color-below-ring  veil-type veil-color weight ring-number ring-type  \
# ...

# %%
test.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           f         g       t    n               f            c
# 1         x           y         g       f    f               f            c
# 2         b           s         w       t    a               f            c
# 3         f           y         y       f    f               f            c
# 4         b           y         y       t    a               f            c
#
#   gill-size gill-color stalk-shape   ...   stalk-color-above-ring  \
# 0         b          u           t   ...                        p
# 1         b          g           e   ...                        b
# 2         b          w           e   ...                        w
# 3         b          p           e   ...                        n
# 4         b          w           e   ...                        w
#
#    stalk-color-below-ring veil-type veil-color weight ring-number ring-type  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5686 entries, 0 to 5685
# Data columns (total 25 columns):
# class                       5686 non-null object
# cap-shape                   5686 non-null object
# cap-surface                 5686 non-null object
# cap-color                   5686 non-null object
# bruises                     5686 non-null object
# odor                        5686 non-null object
# gill-attachment             5686 non-null object
# gill-spacing                5686 non-null object
# gill-size                   5686 non-null object
# gill-color                  5686 non-null object
# stalk-shape                 5686 non-null object
# stalk-root                  5686 non-null object
# radius                      5686 non-null int64
# stalk-surface-above-ring    5686 non-null object
# stalk-surface-below-ring    5686 non-null object
# stalk-color-above-ring      5686 non-null object
# stalk-color-below-ring      5686 non-null object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
for col in test.columns:
    if((col!='radius') and (col!='weight')):
        train[col]=encoder.fit_transform(train[col])
        test[col]=encoder.transform(test[col])

l_class=LabelEncoder()        
train['class']=l_class.fit_transform(train['class'])

# %%
#for col in test.columns:
#    print(train.groupby(col).size())

# %%
train=train.drop(['veil-type'],axis=1)
test=test.drop(['veil-type'],axis=1)

# %%
for col in test.columns:
    if((col!='radius') and (col!='weight')):
        plt.figure(figsize=(5,5))
        arr=sns.violinplot(train[col],train['class'])
        print(train.groupby(col).size())
        plt.show()
# Out:
# cap-shape
# 0     312
# 1       4
# 2    2179
# 3     590
# 4      23
# 5    2578
# dtype: int64
# cap-surface
# 0    1624
# 1       4
# 2    1763
# 3    2295
# dtype: int64
# cap-color
# 0     112
# 1      32
# 2    1050
# 3    1292
# 4    1600
# 5     104
# 6       8
# 7      12
# 8     720
# 9     756
# dtype: int64
# bruises
# 0    3298
# 1    2388
# dtype: int64
# odor
# 0     270
# 1     127
# 2    1501
# 3     280
# 4      24
# 5    2487
# 6     188
# 7     411
# 8     398
# dtype: int64
# gill-attachment
# 0     134
# 1    5552
# dtype: int64
# gill-spacing
# 0    4769
# 1     917
# dtype: int64
# gill-size
# 0    3929
# 1    1757
# dtype: int64
# gill-color
# 0     1200
# 1       70
# 2      526
# 3      530
# 4      269
# 5      728
# 6       39
# 7     1066
# 8       17
# 9      341
# 10     844
# 11      56
# dtype: int64
# stalk-shape
# 0    2462
# 1    3224
# dtype: int64
# stalk-root
# 0    1727
# 1    2665
# 2     382
# 3     780
# 4     132
# dtype: int64
# ...

# %%
plt.figure(figsize=(5,5))
arr=sns.kdeplot(train['radius'],train['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
arr=sns.kdeplot(train['weight'],train['class'])
plt.show()

# %%
remaning=train.loc[train['odor']==5].drop(['odor'],axis=1)
remaning.head()
# Out:
#     class  cap-shape  cap-surface  cap-color  bruises  gill-attachment  \
# 2       0          2            2          4        1                1
# 6       0          2            2          3        0                1
# 7       0          2            0          4        1                1
# 13      0          2            0          3        1                1
# 15      0          5            3          8        0                1
#
#     gill-spacing  gill-size  gill-color  stalk-shape   ...     \
# 2              0          0           1            0   ...
# 6              1          0           7            1   ...
# 7              0          0           9            1   ...
# 13             0          0           9            1   ...
# 15             0          1           7            0   ...
#
#     stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 2                          2                       2                       2
# ...

# %%
for col in remaning.columns:
    if((col!='radius') and (col!='weight') and (col!='class')):
        plt.figure(figsize=(5,5))
        arr=sns.violinplot(remaning[col],remaning['class'])
        print(remaning.groupby(col).size())
        plt.show()
# Out:
# cap-shape
# 0     145
# 1       4
# 2    1031
# 3     171
# 4      23
# 5    1113
# dtype: int64
# cap-surface
# 0    1065
# 1       4
# 2     611
# 3     807
# dtype: int64
# cap-color
# 0     49
# 1     24
# 2    453
# 3    728
# 4    811
# 5     60
# 6      8
# 7     12
# 8    322
# 9     20
# dtype: int64
# bruises
# 0    1036
# 1    1451
# dtype: int64
# gill-attachment
# 0     121
# 1    2366
# dtype: int64
# gill-spacing
# 0    1700
# 1     787
# dtype: int64
# gill-size
# 0    2313
# 1     174
# dtype: int64
# gill-color
# 1      70
# 2     107
# 3     149
# 4     134
# 5     494
# 6      39
# 7     545
# 8      17
# 9     312
# 10    575
# 11     45
# dtype: int64
# stalk-shape
# 0     730
# 1    1757
# dtype: int64
# stalk-root
# 0     527
# 1    1360
# 2       8
# 3     592
# dtype: int64
# stalk-surface-above-ring
# 0     278
# 1     125
# 2    2063
# 3      21
# dtype: int64
# stalk-surface-below-ring
# 0     308
# 1     104
# 2    2030
# 3      45
# dtype: int64
# ...

# %%
remaning=remaning.loc[remaning['spore-print-color']==7].drop(['spore-print-color'],axis=1)
remaning.head()
# Out:
#     class  cap-shape  cap-surface  cap-color  bruises  gill-attachment  \
# 2       0          2            2          4        1                1
# 21      0          0            2          3        0                1
# 34      0          5            0          3        0                1
# 36      0          3            2          8        0                1
# 37      0          0            0          8        0                1
#
#     gill-spacing  gill-size  gill-color  stalk-shape   ...     \
# 2              0          0           1            0   ...
# 21             1          0           7            0   ...
# 34             1          0           7            0   ...
# 36             1          0           7            0   ...
# 37             1          0           7            0   ...
#
#     stalk-surface-above-ring  stalk-surface-below-ring  \
# 2                          2                         2
# 21                         1                         1
# ...

# %%
for col in remaning.columns:
    if((col!='radius') and (col!='weight') and (col!='class')):
        plt.figure(figsize=(5,5))
        arr=sns.violinplot(remaning[col],remaning['class'])
        print(remaning.groupby(col).size())
        plt.show()
# Out:
# cap-shape
# 0     84
# 1      4
# 2     87
# 3    144
# 5    139
# dtype: int64
# cap-surface
# 0    127
# 1      4
# 2    198
# 3    129
# dtype: int64
# cap-color
# 0     33
# 1     24
# 2     33
# 3    111
# 4     81
# 5     42
# 8    114
# 9     20
# dtype: int64
# bruises
# 0    291
# 1    167
# dtype: int64
# gill-attachment
# 1    458
# dtype: int64
# gill-spacing
# 0    196
# 1    262
# dtype: int64
# gill-size
# 0    383
# 1     75
# dtype: int64
# gill-color
# 1      70
# 2      71
# 7      71
# 10    242
# 11      4
# dtype: int64
# stalk-shape
# 0    458
# dtype: int64
# stalk-root
# 0    374
# 1     76
# 2      8
# dtype: int64
# stalk-surface-above-ring
# 0     17
# 1    125
# 2    295
# 3     21
# dtype: int64
# stalk-surface-below-ring
# 0     17
# 1    104
# 2    292
# 3     45
# dtype: int64
# stalk-color-above-ring
# 2     70
# 4     13
# 7    367
# 8      8
# dtype: int64
# stalk-color-below-ring
# 2     69
# 4     59
# 7    309
# 8     21
# dtype: int64
# ...

# %%
remaning=remaning.loc[remaning['gill-size']==1].drop(['gill-size'],axis=1)
remaning.head()
# Out:
#      class  cap-shape  cap-surface  cap-color  bruises  gill-attachment  \
# 257      0          2            0          4        0                1
# 375      0          3            3          4        0                1
# 409      0          5            3          1        0                1
# 435      0          5            3          4        0                1
# 549      0          2            0          4        0                1
#
#      gill-spacing  gill-color  stalk-shape  stalk-root   ...     \
# 257             1          10            0           1   ...
# 375             1          10            0           1   ...
# 409             1          10            0           1   ...
# 435             1          10            0           1   ...
# 549             1          10            0           1   ...
#
#      stalk-surface-above-ring  stalk-surface-below-ring  \
# 257                         0                         0
# ...

# %%
for col in remaning.columns:
    if((col!='radius') and (col!='weight') and (col!='class')):
        plt.figure(figsize=(5,5))
        arr=sns.violinplot(remaning[col],remaning['class'])
        print(remaning.groupby(col).size())
        plt.show()
# Out:
# cap-shape
# 0     8
# 1     4
# 2    24
# 3    20
# 5    19
# dtype: int64
# cap-surface
# 0    27
# 1     4
# 3    44
# dtype: int64
# cap-color
# 1    20
# 4    27
# 8     8
# 9    20
# dtype: int64
# bruises
# 0    67
# 1     8
# dtype: int64
# gill-attachment
# 1    75
# dtype: int64
# gill-spacing
# 0    24
# 1    51
# dtype: int64
# gill-color
# 10    71
# 11     4
# dtype: int64
# stalk-shape
# 0    75
# dtype: int64
# stalk-root
# 0    24
# 1    43
# 2     8
# dtype: int64
# stalk-surface-above-ring
# 0    17
# 1    24
# 2    26
# 3     8
# dtype: int64
# stalk-surface-below-ring
# 0    17
# 2    26
# 3    32
# dtype: int64
# stalk-color-above-ring
# 7    67
# 8     8
# dtype: int64
# stalk-color-below-ring
# 4    46
# 7     8
# 8    21
# dtype: int64
# veil-color
# 2    67
# 3     8
# dtype: int64
# ring-number
# 1    75
# dtype: int64
# ring-type
# 0    67
# 4     8
# dtype: int64
# population
# 1    16
# 4    59
# dtype: int64
# habitat
# 0    24
# 2    51
# dtype: int64

# %%
remaning=remaning.loc[remaning['cap-color']==4].drop(['cap-color'],axis=1)
remaning.head()

for col in remaning.columns:
    if((col!='radius') and (col!='weight') and (col!='class')):
        plt.figure(figsize=(5,5))
        arr=sns.violinplot(remaning[col],remaning['class'])
        print(remaning.groupby(col).size())
        plt.show()
# Out:
# cap-shape
# 0    2
# 2    9
# 3    8
# 5    8
# dtype: int64
# cap-surface
# 0    11
# 3    16
# dtype: int64
# bruises
# 0    27
# dtype: int64
# gill-attachment
# 1    27
# dtype: int64
# gill-spacing
# 0    12
# 1    15
# dtype: int64
# gill-color
# 10    27
# dtype: int64
# stalk-shape
# 0    27
# dtype: int64
# stalk-root
# 0    12
# 1    15
# dtype: int64
# stalk-surface-above-ring
# 0     7
# 1    12
# 2     8
# dtype: int64
# stalk-surface-below-ring
# 0     8
# 2     7
# 3    12
# dtype: int64
# stalk-color-above-ring
# 7    27
# dtype: int64
# stalk-color-below-ring
# 4    21
# 8     6
# dtype: int64
# veil-color
# 2    27
# dtype: int64
# ring-number
# 1    27
# dtype: int64
# ring-type
# 0    27
# dtype: int64
# population
# 4    27
# dtype: int64
# habitat
# 0    12
# 2    15
# dtype: int64

# %%
train_final=train[['class','odor','spore-print-color','gill-size','cap-color','habitat']]
test_final=test[['odor','spore-print-color','gill-size','cap-color','habitat']]

# %% [markdown]
# What all I did above is what a tree classifier do.
# So we can apply direct tree classification in our selected columns(or in whole dataset, both will give same result).

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(train_final.drop(['class'],axis=1),train_final['class'])

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score
extra=ExtraTreesClassifier(n_estimators=200,n_jobs=-1).fit(x_train,y_train).predict(x_test)
accuracy_score(y_test,extra)
# Out:
# 1.0

# %%
prediction=ExtraTreesClassifier(n_estimators=200,n_jobs=-1).fit(train_final.drop(['class'],axis=1),train_final['class']).predict(test_final)

# %%
test['class']=l_class.inverse_transform(prediction)

# %%
test.to_csv('prediction.csv',index=False)
